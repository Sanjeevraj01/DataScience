# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjeevraj01/DataScience/blob/main/Stock_Max_and_Min_Gain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b46ba39a-04b1-4a51-b9f9-8b75be87dee8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b46ba39a-04b1-4a51-b9f9-8b75be87dee8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
glaxo = pd.read_csv('GLAXO.csv')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-aa7dba55-2c2f-4497-937b-9f976bad60c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aa7dba55-2c2f-4497-937b-9f976bad60c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
beml = pd.read_csv('BEML.csv')

# %%
beml.head()
# Out:
#          Date    Open     High      Low    Last    Close  \
# 0  2010-01-04  1121.0  1151.00  1121.00  1134.0  1135.60
# 1  2010-01-05  1146.8  1149.00  1128.75  1135.0  1134.60
# 2  2010-01-06  1140.0  1164.25  1130.05  1137.0  1139.60
# 3  2010-01-07  1142.0  1159.40  1119.20  1141.0  1144.15
# 4  2010-01-08  1156.0  1172.00  1140.00  1141.2  1144.05
#
#    Total Trade Quantity  Turnover (Lacs)
# 0              101651.0          1157.18
# 1               59504.0           676.47
# 2              128908.0          1482.84
# 3              117871.0          1352.98
# 4              170063.0          1971.42

# %%
beml= beml[['Date','Close']]
glaxo= glaxo[['Date','Close']]

# %%
beml
# Out:
#             Date    Close
# 0     2010-01-04  1135.60
# 1     2010-01-05  1134.60
# 2     2010-01-06  1139.60
# 3     2010-01-07  1144.15
# 4     2010-01-08  1144.05
# ...          ...      ...
# 1734  2016-12-26   950.25
# 1735  2016-12-27   975.70
# 1736  2016-12-28   974.40
# 1737  2016-12-29   986.05
# 1738  2016-12-30  1000.60
#
# [1739 rows x 2 columns]

# %%
glaxo = glaxo.set_index(pd.DatetimeIndex(glaxo['Date'])).drop('Date',axis=1)
beml = beml.set_index(pd.DatetimeIndex(beml['Date'])).drop('Date',axis=1)

# %%
import matplotlib.pyplot as plt
import seaborn as sn
plt.plot(glaxo.Close);
plt.xlabel('Time');
plt.ylabel('Close price');

# %%
plt.plot(beml.Close);
plt.xlabel('Time');
plt.ylabel('Close price');

# %%
glaxo['gain','gain2'] = glaxo.Close.pct_change(periods = 2)

# %%
glaxo = glaxo.drop (['gain'],axis = 1)
glaxo
# Out:
#               Close  (gain, gain2)
# Date
# 2010-01-04  1625.65            NaN
# 2010-01-05  1616.80            NaN
# 2010-01-06  1638.50       0.007905
# 2010-01-07  1648.70       0.019730
# 2010-01-08  1639.80       0.000793
# ...             ...            ...
# 2016-12-26  2723.50       0.003685
# 2016-12-27  2701.75      -0.009259
# 2016-12-28  2702.15      -0.007839
# 2016-12-29  2727.90       0.009679
# 2016-12-30  2729.80       0.010233
#
# [1739 rows x 2 columns]
